# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

url = 'https://raw.githubusercontent.com/fivethirtyeight/data/master/alcohol-consumption/drinks.csv'
alcohol_df = pd.read_csv(url)
alcohol_df.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol
# 0                           0.0
# 1                           4.9
# 2                           0.7
# 3                          12.4
# 4                           5.9

# %%
alcohol_df.loc[alcohol_df['beer_servings'] == 0]
# Out:
#               country  beer_servings  spirit_servings  wine_servings  \
# 0         Afghanistan              0                0              0
# 13         Bangladesh              0                0              0
# 40       Cook Islands              0              254             74
# 46        North Korea              0                0              0
# 79               Iran              0                0              0
# 90             Kuwait              0                0              0
# 97              Libya              0                0              0
# 103          Maldives              0                0              0
# 106  Marshall Islands              0                0              0
# 107        Mauritania              0                0              0
# 111            Monaco              0                0              0
# 128          Pakistan              0                0              0
# 147        San Marino              0                0              0
# ...

# %%
#data_set = alcohol_df.loc[alcohol_df['total_litres_of_pure_alcohol'] >= 9]
#data_set = data_set.drop(data_set.columns[[1,2, 3]], axis=1)
#print(data_set)
#sns.distplot(data_set['total_litres_of_pure_alcohol']);

#p = sns.lineplot(data = data_set)
#plt.xlabel("pure alco")
#plt.ylabel("Country")

# %%
data_set = alcohol_df.loc[alcohol_df['total_litres_of_pure_alcohol'] >= 9]
data_set = data_set.drop(data_set.columns[[1,2, 3]], axis=1)
#df = pd.DataFrame({'s_x':s_x,'s_y':s_y})

g = sns.scatterplot(data = data_set, y  = data_set['total_litres_of_pure_alcohol'], x = 'country')

g.set_xticklabels(data_set['country'], rotation =90)
# Out:
# [Text(0, 0, 'Andorra'),
#  Text(0, 0, 'Australia'),
#  Text(0, 0, 'Austria'),
#  Text(0, 0, 'Belarus'),
#  Text(0, 0, 'Belgium'),
#  Text(0, 0, 'Bulgaria'),
#  Text(0, 0, 'Croatia'),
#  Text(0, 0, 'Czech Republic'),
#  Text(0, 0, 'Denmark'),
#  Text(0, 0, 'Estonia'),
#  Text(0, 0, 'Finland'),
#  Text(0, 0, 'France'),
#  Text(0, 0, 'Germany'),
#  Text(0, 0, 'Grenada'),
#  Text(0, 0, 'Hungary'),
#  Text(0, 0, 'Ireland'),
#  Text(0, 0, 'Latvia'),
#  Text(0, 0, 'Lithuania'),
#  Text(0, 0, 'Luxembourg'),
#  Text(0, 0, 'Netherlands'),
#  Text(0, 0, 'New Zealand'),
#  Text(0, 0, 'Nigeria'),
#  Text(0, 0, 'Poland'),
#  Text(0, 0, 'Portugal'),
#  Text(0, 0, 'South Korea'),
#  Text(0, 0, 'Romania'),
#  Text(0, 0, 'Russian Federation'),
#  Text(0, 0, 'St. Lucia'),
#  Text(0, 0, 'Serbia'),
#  Text(0, 0, 'Slovakia'),
#  Text(0, 0, 'Slovenia'),
#  Text(0, 0, 'Spain'),
#  Text(0, 0, 'Switzerland'),
#  Text(0, 0, 'United Kingdom')]

# %%
alcohol_df[alcohol_df['country'].str.contains("stan")]
pure_alc = alcohol_df[alcohol_df['country'].str.contains("stan")]
alc = pure_alc['total_litres_of_pure_alcohol']
print("Sum of pure alco" , alc.mean())
alcohol_df[alcohol_df['country'].str.contains("stan")]
# Out:
# Sum of pure alco 2.0142857142857142
#           country  beer_servings  spirit_servings  wine_servings  \
# 0     Afghanistan              0                0              0
# 87     Kazakhstan            124              246             12
# 91     Kyrgyzstan             31               97              6
# 128      Pakistan              0                0              0
# 168    Tajikistan              2               15              0
# 177  Turkmenistan             19               71             32
# 186    Uzbekistan             25              101              8
#
#      total_litres_of_pure_alcohol
# 0                             0.0
# 87                            6.8
# 91                            2.4
# 128                           0.0
# 168                           0.3
# 177                           2.2
# 186                           2.4

# %%
beer = alcohol_df.nlargest(10, 'beer_servings')
beer = beer.drop(beer.columns[[2, 3, 4]], axis=1)
print(beer.to_string(index=False))
# Out:
#        country  beer_servings
#        Namibia            376
# Czech Republic            361
#          Gabon            347
#        Germany            346
#      Lithuania            343
#         Poland            343
#      Venezuela            333
#        Ireland            313
#          Palau            306
#        Romania            297

# %%
spirit = alcohol_df.nlargest(10, 'spirit_servings')
spirit = spirit.drop(spirit.columns[[1, 3, 4]], axis=1)
print(spirit.to_string(index=False))
# Out:
#            country  spirit_servings
#            Grenada              438
#            Belarus              373
#              Haiti              326
# Russian Federation              326
#          St. Lucia              315
#             Guyana              302
#           Slovakia              293
#           Dominica              286
#           Thailand              258
#       Cook Islands              254

# %%
wine = alcohol_df.nlargest(10, 'wine_servings')
wine = wine.drop(wine.columns[[1, 2, 4]], axis=1)
print(wine.to_string(index=False))
# Out:
#           country  wine_servings
#            France            370
#          Portugal            339
#           Andorra            312
#       Switzerland            280
#           Denmark            278
#          Slovenia            276
#        Luxembourg            271
#           Croatia            254
#             Italy            237
# Equatorial Guinea            233

# %%
alcohol_df.nlargest(10,['spirit_servings'])
# Out:
#                 country  beer_servings  spirit_servings  wine_servings  \
# 68              Grenada            199              438             28
# 15              Belarus            142              373             42
# 73                Haiti              1              326              1
# 141  Russian Federation            247              326             73
# 144           St. Lucia            171              315             71
# 72               Guyana             93              302              1
# 155            Slovakia            196              293            116
# 50             Dominica             52              286             26
# 169            Thailand             99              258              1
# 40         Cook Islands              0              254             74
#
#      total_litres_of_pure_alcohol
# 68                           11.9
# 15                           14.4
# 73                            5.9
# 141                          11.5
# ...
